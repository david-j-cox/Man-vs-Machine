# %%
cd /Users/dcox/Dropbox/Projects/CurrentProjectManuscripts/Empirical/PersonalFun/Matching/KaggleWebscrapingAnalysis/data
# Out:
# /Users/dcox/Dropbox/Projects/CurrentProjectManuscripts/Empirical/PersonalFun/Matching/KaggleWebscrapingAnalysis/data

# %%
# !pwd
# Out:
# /Users/dcox/Dropbox/Projects/CurrentProjectManuscripts/Empirical/PersonalFun/Matching/KaggleWebscrapingAnalysis/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in data
at_bats = pd.read_csv('atbats.csv')
games = pd.read_csv('games.csv')
pitches = pd.read_csv('pitches.csv')

# %%
print("at_bats:", list(at_bats), "\n\npitches:", list(pitches), "\n\ndata:", list(data))
# Out:
# at_bats: ['ab_id', 'batter_id', 'event', 'g_id', 'inning', 'o', 'p_score', 'p_throws', 'pitcher_id', 'stand', 'top']
#
# pitches: ['px', 'pz', 'start_speed', 'end_speed', 'spin_rate', 'spin_dir', 'break_angle', 'break_length', 'break_y', 'ax', 'ay', 'az', 'sz_bot', 'sz_top', 'type_confidence', 'vx0', 'vy0', 'vz0', 'x', 'x0', 'y', 'y0', 'z0', 'pfx_x', 'pfx_z', 'nasty', 'zone', 'code', 'type', 'pitch_type', 'event_num', 'b_score', 'ab_id', 'b_count', 's_count', 'outs', 'pitch_num', 'on_1b', 'on_2b', 'on_3b']
#
# data: ['px', 'pz', 'start_speed', 'end_speed', 'spin_rate', 'spin_dir', 'break_angle', 'break_length', 'break_y', 'ax', 'ay', 'az', 'sz_bot', 'sz_top', 'type_confidence', 'vx0', 'vy0', 'vz0', 'x', 'x0', 'y', 'y0', 'z0', 'pfx_x', 'pfx_z', 'nasty', 'zone', 'code', 'type', 'pitch_type', 'event_num', 'b_score', 'ab_id', 'b_count', 's_count', 'outs', 'pitch_num', 'on_1b', 'on_2b', 'on_3b', 'batter_id', 'event', 'g_id', 'inning', 'o', 'p_score', 'p_throws', 'pitcher_id', 'stand', 'top']

# %%
# Left join pitches and at_bats on ab_id column
data = pitches.merge(at_bats, on='ab_id', how='left')

# %%
data.to_csv('merged_data.csv')

# %%
data_cols = list(data)
for i in data_cols:
    print("\n", i, "\n", data[i].value_counts())
# Out:
#  px
#  -0.200000    1218
# -0.030000    1217
#  0.130000    1216
# -0.190000    1210
# -0.020000    1208
#              ...
#  1.010811       1
# -0.429176       1
#  0.608892       1
# -0.467476       1
# -1.018109       1
# Name: px, Length: 1449037, dtype: int64
#
#  pz
#  2.100000    1270
# 2.340000    1262
# 2.180000    1259
# 2.190000    1243
# 2.150000    1241
#             ...
# 1.729281       1
# 1.494763       1
# 4.332732       1
# 3.499688       1
# 2.469192       1
# Name: pz, Length: 1447427, dtype: int64
#
#  start_speed
#  92.3    24794
# 92.4    24731
# 92.5    24677
# 92.7    24579
# 91.8    24538
#         ...
# 41.3        1
# 41.2        1
# 40.3        1
# 40.8        1
# 40.0        1
# Name: start_speed, Length: 627, dtype: int64
#
#  end_speed
#  84.7    27060
# 84.6    26997
# 84.8    26948
# 85.0    26699
# 84.5    26667
#         ...
# 38.9        1
# 41.8        1
# 41.2        1
# 44.2        1
# 41.9        1
# Name: end_speed, Length: 574, dtype: int64
#
#  spin_rate
#  2254.075    12
# 2178.673    11
# 2315.815    11
# 2071.850    10
# 2140.897    10
#             ..
# 1323.327     1
# 1332.673     1
# 2998.671     1
# 860.677      1
# 512.000      1
# Name: spin_rate, Length: 1687547, dtype: int64
#
#  spin_dir
#  180.002    64
# 206.432    48
# 208.370    48
# 206.876    47
# 206.268    47
#            ..
# 321.663     1
# 1.757       1
# 17.776      1
# 321.032     1
# 85.993      1
# Name: spin_dir, Length: 335091, dtype: int64
#
#  break_angle
#  -7.7      5214
# -7.8      5122
# -8.6      5115
# -7.5      5091
# -8.2      5087
#           ...
# -77.1        1
#  163.2       1
#  168.6       1
#  108.2       1
#  85.1        1
# Name: break_angle, Length: 1698, dtype: int64
#
#  break_length
#  4.0     52250
# 4.1     52125
# 4.2     51659
# 3.9     51114
# 4.3     50946
#         ...
# 28.9        1
# 28.4        1
# 36.6        1
# 29.6        1
# 22.4        1
# Name: break_length, Length: 307, dtype: int64
#
#  break_y
#  23.8    1717395
# 23.9     774543
# 23.7     323379
# 24.0      25970
# 23.6      11307
# 23.5        171
# 24.1        158
# 24.2         23
# 23.4         12
# 23.3          3
# 24.4          2
# 24.3          1
# 36.4          1
# Name: break_y, dtype: int64
#
#  ax
#  -10.450000    132
# -11.350000    128
# -12.000000    126
# -12.300000    126
# -10.710000    124
#              ...
#  4.164471       1
# -16.146982      1
#  0.897668       1
# -4.621044       1
# -4.040221       1
# Name: ax, Length: 1489862, dtype: int64
#
#  ay
#  27.160000    271
# 25.410000    265
# 28.280000    264
# 25.390000    262
# 26.950000    261
#             ...
# 29.328918      1
# 25.318097      1
# 22.120495      1
# 20.384556      1
# 24.832065      1
# Name: ay, Length: 1467412, dtype: int64
#
#  az
#  -15.410000    159
# -15.110000    155
# -15.030000    155
# -17.210000    154
# -17.670000    153
#              ...
# -20.652684      1
# -15.699335      1
# -22.510511      1
# -13.834810      1
# -17.157978      1
# Name: az, Length: 1483765, dtype: int64
#
#  sz_bot
#  1.600000    58342
# 1.590000    57637
# 1.550000    56713
# 1.560000    55985
# 1.570000    55883
#             ...
# 1.679135        1
# 1.520983        1
# 1.566256        1
# 1.564688        1
# 1.671603        1
# Name: sz_bot, Length: 775602, dtype: int64
#
#  sz_top
#  3.490000    45849
# 3.470000    34779
# 3.500000    34265
# 3.560000    32280
# 3.410000    31698
#             ...
# 3.073311        1
# 3.217953        1
# 3.109740        1
# 3.471478        1
# 3.146625        1
# Name: sz_top, Length: 802477, dtype: int64
#
#  type_confidence
#  2.000    1711162
# 0.902      47533
# 0.901      43996
# 0.903      43540
# 0.900      38423
#           ...
# 1.013          1
# 0.238          1
# 1.091          1
# 1.224          1
# 1.140          1
# Name: type_confidence, Length: 1109, dtype: int64
#
#  vx0
#   4.550000    298
#  4.670000    297
#  4.970000    296
#  5.210000    295
#  4.520000    295
#             ...
#  8.451019      1
# -6.495997      1
#  9.688320      1
#  2.996519      1
#  8.814308      1
# Name: vx0, Length: 1470575, dtype: int64
#
#  vy0
#  -134.610000    207
# -135.100000    196
# -134.290000    195
# -135.140000    194
# -134.810000    193
#               ...
# -126.099487      1
# -134.258323      1
# -137.147615      1
# -124.730559      1
# -142.216469      1
# Name: vy0, Length: 1488641, dtype: int64
#
#  vz0
#  -4.720000    409
# -4.820000    407
# -4.530000    403
# -5.400000    399
# -5.070000    398
#             ...
# -6.955504      1
# -5.515204      1
# -5.657360      1
# -7.325355      1
# -3.557421      1
# Name: vz0, Length: 1460451, dtype: int64
#
#  x
#  1.000000      10654
# 0.000000       6615
# 119.250000      845
# 121.000000      844
# 110.560000      842
#               ...
# 72.155121         1
# 243.530000        1
# 105.009215        1
# 59.757710         1
# 106.123428        1
# Name: x, Length: 26880, dtype: int64
#
#  x0
#  -1.360000    1166
# -1.440000    1117
# -1.290000    1113
# -1.620000    1109
# -1.660000    1108
#              ...
# -2.583453       1
# -1.790305       1
# -2.042035       1
# -1.313608       1
# -1.023899       1
# Name: x0, Length: 1448198, dtype: int64
#
#  y
#  0.000000      12577
# 1.000000      10654
# 176.490000      946
# 177.140000      937
# 173.740000      935
#               ...
# 100.550000        1
# 107.112909        1
# 96.428521         1
# 192.670779        1
# 85.650000         1
# Name: y, Length: 21690, dtype: int64
#
#  y0
#  50.0    2533400
# 50.0     134065
# 50.0      98608
# 50.0      13926
# 50.0      13368
# 50.0       8840
# 50.0       7865
# 50.0       7764
# 50.0       6859
# 50.0       6066
# 50.0       4601
# 50.0       4494
# 50.0       3993
# 50.0       3222
# 50.0       2697
# 50.0       1491
# 50.0        693
# 50.0        581
# 50.0        394
# 50.0         16
# 50.0          7
# 50.0          6
# 50.0          6
# 50.0          1
# 50.0          1
# 50.0          1
# Name: y0, dtype: int64
#
#  z0
#  5.920000    2785
# 5.980000    2755
# 5.880000    2746
# 5.910000    2738
# 5.900000    2735
#             ...
# 5.456787       1
# 5.793677       1
# 5.758928       1
# 5.659630       1
# 5.044946       1
# Name: z0, Length: 1444172, dtype: int64
#
#  pfx_x
#  -6.450000    1021
# -6.710000    1015
# -6.590000    1002
# -5.900000     999
# -6.470000     999
#              ...
#  2.405900       1
#  9.069765       1
# -0.364799       1
# -8.472893       1
# -8.383662       1
# Name: pfx_x, Length: 1446249, dtype: int64
#
#  pfx_z
#  8.530000    1411
# 8.850000    1409
# 8.570000    1407
# 8.550000    1390
# 8.470000    1380
#             ...
# 9.210459       1
# 2.905128       1
# 3.474283       1
# 3.342558       1
# 9.097965       1
# Name: pfx_z, Length: 1446096, dtype: int64
#
#  nasty
#  44.0    66632
# 40.0    65204
# 45.0    64723
# 41.0    64703
# 47.0    64311
#         ...
# 98.0      841
# 99.0      757
# 4.0       728
# 2.0       361
# 1.0        49
# Name: nasty, Length: 101, dtype: int64
#
#  zone
#  14.0    604677
# 13.0    481480
# 11.0    365635
# 12.0    271762
# 5.0     158369
# 8.0     144854
# 4.0     140820
# 6.0     140052
# 9.0     135701
# 7.0     124147
# 2.0     104105
# 1.0      94675
# 3.0      86688
# Name: zone, dtype: int64
#
#  code
#  B     956646
# F     496512
# C     480903
# X     330875
# S     271330
# D     117123
# *B     65675
# E      64166
# T      23947
# W      23137
# L       8471
# H       6938
# V       6652
# I       6588
# M       1844
# P        619
# Q          6
# R          2
# Z          1
# Name: code, dtype: int64
#
#  type
#  S    1308865
# B    1045126
# X     513163
# Name: type, dtype: int64
#
#  pitch_type
#  FF    1014877
# SL     450578
# FT     337983
# CH     292789
# SI     242504
# CU     234391
# FC     149756
# KC      66484
# FS      43705
# KN      11260
# IN       6197
# EP        815
# FO        810
# PO        628
# SC        113
# UN         57
# AB          9
# FA          9
# Name: pitch_type, dtype: int64
#
#  event_num
#  3       9695
# 4       8850
# 5       7199
# 12      5881
# 11      5783
#         ...
# 1259       1
# 1267       1
# 1268       1
# 1272       1
# 1336       1
# Name: event_num, Length: 1277, dtype: int64
#
#  b_score
#  0.0     920857
# 1.0     517992
# 2.0     406935
# 3.0     309245
# 4.0     229724
# 5.0     162429
# 6.0     111613
# 7.0      74458
# 8.0      50020
# 9.0      30391
# 10.0     21444
# 11.0     12746
# 12.0      7947
# 13.0      4419
# 14.0      2751
# 15.0      1561
# 16.0      1045
# 17.0       751
# 19.0       296
# 18.0       268
# 20.0       102
# 21.0       102
# 22.0        23
# 23.0        14
# 24.0        14
# 25.0         7
# Name: b_score, dtype: int64
#
#  ab_id
#  2.018024e+09    21
# 2.016062e+09    18
# 2.017184e+09    17
# 2.018059e+09    17
# 2.018172e+09    17
#                 ..
# 2.018005e+09     1
# 2.018147e+09     1
# 2.016073e+09     1
# 2.017175e+09     1
# 2.018083e+09     1
# Name: ab_id, Length: 740241, dtype: int64
#
#  b_count
#  0.0    1292084
# 1.0     855623
# 2.0     483926
# 3.0     235508
# 4.0         13
# Name: b_count, dtype: int64
#
#  s_count
#  0.0    1166892
# 1.0     874311
# 2.0     825951
# Name: s_count, dtype: int64
#
#  outs
#  0.0    983429
# 1.0    950175
# 2.0    933550
# Name: outs, dtype: int64
#
#  pitch_num
#  1.0     740241
# 2.0     658455
# 3.0     544513
# 4.0     411226
# 5.0     269681
# 6.0     145427
# 7.0      60172
# 8.0      23601
# 9.0       8849
# 10.0      3216
# 11.0      1133
# 12.0       410
# 13.0       150
# 14.0        48
# 15.0        16
# 16.0         6
# 17.0         5
# 18.0         2
# 19.0         1
# 21.0         1
# 20.0         1
# Name: pitch_num, dtype: int64
#
#  on_1b
#  0.0    2001757
# 1.0     865397
# Name: on_1b, dtype: int64
#
#  on_2b
#  0.0    2333734
# 1.0     533420
# Name: on_2b, dtype: int64
#  on_3b
#  0.0    2592035
# 1.0     275119
# Name: on_3b, dtype: int64
#
#  batter_id
#  502671    11688
# 458015    11244
# 467793    11134
# 572821    11119
# 457705    11051
#           ...
# 453307        1
# 449170        1
# 472610        1
# 643414        1
# 642558        1
# Name: batter_id, Length: 1688, dtype: int64
#
#  event
#  Strikeout               757160
# Groundout               469560
# Single                  368621
# Walk                    327001
# Flyout                  273909
# Lineout                 154000
# Pop Out                 118552
# Double                  112074
# Home Run                 75075
# Forceout                 47442
# Grounded Into DP         45873
# Field Error              22237
# Hit By Pitch             21764
# Sac Fly                  15508
# Intent Walk              15346
# Triple                   11872
# Sac Bunt                  7526
# Double Play               5905
# Runner Out                4234
# Fielders Choice Out       3992
# Strikeout - DP            3654
# Bunt Groundout            2184
# Fielders Choice           1243
# Bunt Pop Out               974
# Catcher Interference       543
# Batter Interference        516
# Sac Fly DP                 229
# Bunt Lineout                91
# Triple Play                 60
# Sacrifice Bunt DP            9
# Name: event, dtype: int64
#
#  g_id
#  201500047    628
# 201601191    606
# 201700459    593
# 201700744    572
# 201501369    558
#             ...
# 201501673    182
# 201801498    175
# 201500642    152
# 201500430    150
# 201602376    128
# Name: g_id, Length: 9718, dtype: int64
#
#  inning
#  1     333237
# 8     323829
# 7     322073
# 6     319920
# 4     318227
# 2     316917
# 3     316908
# 5     315819
# 9     244579
# 10     25309
# 11     14383
# 12      7560
# 13      4244
# 14      1809
# 15      1076
# 16       693
# 17       308
# 18       191
# 19        72
# Name: inning, dtype: int64
#
#  o
#  1    951062
# 2    929637
# 3    662637
# 0    323818
# Name: o, dtype: int64
#
#  p_score
#  0     944865
# 1     498752
# 2     394876
# 3     297419
# 4     226816
# 5     164337
# 6     114053
# 7      78472
# 8      53613
# 9      32355
# 10     23708
# 11     14717
# 12      9542
# 13      5304
# 14      3262
# 15      2005
# 16      1109
# 17       899
# 19       397
# 18       258
# 21       160
# 20        93
# 22        91
# 25        23
# 23        15
# 24        13
# Name: p_score, dtype: int64
#
#  p_throws
#  R    2098635
# L     768519
# Name: p_throws, dtype: int64
#
#  pitcher_id
#  453286    13534
# 434378    12791
# 502042    12775
# 500779    12763
# 519242    12707
#           ...
# 640447        3
# 448602        3
# 506560        3
# 456121        2
# 519203        2
# Name: pitcher_id, Length: 1332, dtype: int64
#
#  stand
#  R    1665649
# L    1201505
# Name: stand, dtype: int64
#
#  top
#  True     1459495
# False    1407659
# Name: top, dtype: int64

# %%
data.dtypes
data_obj = ['code', 'type', 'pitch_type', 'event', 'p_throws', 'stand', 'top']
data_objs = data[data_obj]

# %%
data_ints = data.drop(data[data_obj], axis=1)
