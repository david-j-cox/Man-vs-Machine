# %% [markdown]
# <a href="https://colab.research.google.com/github/davidjcox333/Man-vs-Machine/blob/master/Nashville_Zip_Batch_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Packages!!
import pandas as pd
import numpy as np
# !pip install uszipcode
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# %cd './gdrive/My Drive/Policing Data'
# %matplotlib inline
# Out:
# ...
#      |████████████████████████████████| 378kB 2.7MB/s
# ...
#      |████████████████████████████████| 81kB 6.6MB/s
# ...
#      |████████████████████████████████| 122kB 10.7MB/s
# ...
#      |████████████████████████████████| 51kB 5.5MB/s
# ...
#   Created wheel for autopep8: filename=autopep8-1.5.3-py2.py3-none-any.whl size=44058 sha256=41b484785df63d86b1fba389dff4bf945874d680b52639584dccd2daf8226e58
#   Stored in directory: /root/.cache/pip/wheels/ab/eb/a9/b52a501381973eb8336db202c06bba1fa8c2e9cd6e09b9bb24
# Successfully built autopep8
# ...
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ...

# %%
# Read in the data
nash_raw_data = pd.read_csv("tn_nashville_2020_04_01.csv")
nash_data = nash_raw_data.copy()
nash_data = nash_data.drop(['Unnamed: 0'], axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,9,16,17,18,23,24,25,26,30,31,32,33,34,36,37,38,39,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Counts by zip code

# %%
length = round(len(nash_data) / 5)
print(length, length*2, length*3, length*4, length*5, "All:", len(nash_data))
# Out:
# 618470 1236940 1855410 2473880 3092350 All: 3092351

# %%
  # Assign a zip code to each observation in batches 
from uszipcode import Zipcode
from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)

ziplist = []

for i in list(range(2473880, 3092351)):
   zip = search.by_coordinates(nash_data['lat'][i], nash_data['lng'][i], radius=5, returns=1)
   val = [zipcode.zipcode for zipcode in zip]
   ziplist.append(val)
   if (i % 1000 == 0):
     print("Still working...ziplist length=%s" %len(ziplist))
   if (i%10000 == 0):
     print("Another 10,000 down")
     obs_zips = pd.DataFrame(ziplist)
     obs_zips.to_csv('zips_5.csv')
# Out:
# Still working...ziplist length=121
# Still working...ziplist length=1121
# Still working...ziplist length=2121
# Still working...ziplist length=3121
# Still working...ziplist length=4121
# Still working...ziplist length=5121
# Still working...ziplist length=6121
# Another 10,000 down
# Still working...ziplist length=7121
# Still working...ziplist length=8121
# Still working...ziplist length=9121
# Still working...ziplist length=10121
# Still working...ziplist length=11121
# Still working...ziplist length=12121
# Still working...ziplist length=13121
# Still working...ziplist length=14121
# Still working...ziplist length=15121
# Still working...ziplist length=16121
# Another 10,000 down
# Still working...ziplist length=17121
# Still working...ziplist length=18121
# Still working...ziplist length=19121
# Still working...ziplist length=20121
# Still working...ziplist length=21121
# Still working...ziplist length=22121
# Still working...ziplist length=23121
# ...

# %%
obs_zips = pd.DataFrame(ziplist)
obs_zips.to_csv('zips_5.csv')
