# %% [markdown]
# <a href="https://colab.research.google.com/github/davidjcox333/Man-vs-Machine/blob/master/RE288_5th_batch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set path to data
from google.colab import drive
drive.mount('/content/gdrive')
# %cd './gdrive/My Drive/Matching with RE288/Data'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Matching with RE288/Data

# %%
# Packages we'll use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
from google.colab import files
import zipfile, io, os
# Load in RE288 game state function; uncomment next line if first time using
#files.upload()
from RE288 import RE288_calc
print("Packages loaded")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Packages loaded

# %%
# Load dfs if starting from here
data_raw = pd.read_csv('All_MLB_data_gs.csv')
df_gs_spec = data_raw.copy()
df_gs_spec = df_gs_spec.drop(['Unnamed: 0', 'RE288'], axis=1)
RE288_AL = pd.read_csv('RE288_AL.csv')
RE288_AL = RE288_AL.drop(['Unnamed: 0'], axis=1)
RE288_NL = pd.read_csv('RE288_NL.csv')
RE288_NL = RE288_NL.drop(['Unnamed: 0'], axis=1)

# %%
# Create AL and NL team lists
AL_teams = ['CLE', 'OAK', 'NYY', 'BAL', 'KC', 'TEX', 'TB', 'LAA', 'TOR', 'CWS', \
            'DET', 'SEA', 'BOS', 'MIN', 'HOU']
NL_teams = ['COL', 'LAD', 'NYM', 'PHI', 'SF', 'STL', 'WSH', 'CHC', 'MIA', 'PIT', \
            'SD', 'ATL', 'CIN', 'MIL', 'ARI']

# %%
# Assign the average run expectancy for each pitch in the df. 
RE288_col = [] # empty list to store our data
RE_range = list(range(len(RE288_NL)))
df_len = list(range(1156500, 1445625))

for i in df_len:
  # Get the game state and year
  gs = df_gs_spec['game_state'][i]
  yr = df_gs_spec['game_year'][i]
  # Find the corresponding RE288
  if (df_gs_spec['home_team'][i] in NL_teams):
    for j in RE_range:
      if RE288_NL['Year'][j]==yr:
        if RE288_NL['Game_State'][j]==gs:
          val = RE288_NL['NL_RE288'][j]
          RE288_col.append(val) # append to col
  else:
    for j in RE_range:
      if RE288_AL['Year'][j]==yr:
        if RE288_AL['Game_State'][j]==gs:
          val = RE288_AL['AL_RE288'][j]
          RE288_col.append(val) # append to col
  if i%1000 == 0:
    print(i, "observations completed")
  if i%5000 == 0:
    save = pd.DataFrame(RE288_col)
    save.to_csv('RE288_5th_batch.csv')

print(len(df_gs_spec))
print(len(RE288_col))
# Out:
# 1157000 observations completed
# 1158000 observations completed
# 1159000 observations completed
# 1160000 observations completed
# 1161000 observations completed
# 1162000 observations completed
# 1163000 observations completed
# 1164000 observations completed
# 1165000 observations completed
# 1166000 observations completed
# 1167000 observations completed
# 1168000 observations completed
# 1169000 observations completed
# 1170000 observations completed
# 1171000 observations completed
# 1172000 observations completed
# 1173000 observations completed
# 1174000 observations completed
# 1175000 observations completed
# 1176000 observations completed
# 1177000 observations completed
# 1178000 observations completed
# 1179000 observations completed
# 1180000 observations completed
# 1181000 observations completed
# 1182000 observations completed
# 1183000 observations completed
# 1184000 observations completed
# 1185000 observations completed
# 1186000 observations completed
# 1187000 observations completed
# 1188000 observations completed
# 1189000 observations completed
# 1190000 observations completed
# 1191000 observations completed
# 1192000 observations completed
# 1193000 observations completed
# 1194000 observations completed
# 1195000 observations completed
# 1196000 observations completed
# 1197000 observations completed
# 1198000 observations completed
# 1199000 observations completed
# 1200000 observations completed
# 1201000 observations completed
# 1202000 observations completed
# 1203000 observations completed
# 1204000 observations completed
# 1205000 observations completed
# 1206000 observations completed
# 1207000 observations completed
# 1208000 observations completed
# 1209000 observations completed
# 1210000 observations completed
# 1211000 observations completed
# 1212000 observations completed
# 1213000 observations completed
# 1214000 observations completed
# 1215000 observations completed
# 1216000 observations completed
# 1217000 observations completed
# 1218000 observations completed
# 1219000 observations completed
# 1220000 observations completed
# 1221000 observations completed
# 1222000 observations completed
# 1223000 observations completed
# 1224000 observations completed
# 1225000 observations completed
# 1226000 observations completed
# 1227000 observations completed
# 1228000 observations completed
# 1229000 observations completed
# 1230000 observations completed
# 1231000 observations completed
# 1232000 observations completed
# 1233000 observations completed
# 1234000 observations completed
# 1235000 observations completed
# 1236000 observations completed
# 1237000 observations completed
# 1238000 observations completed
# 1239000 observations completed
# 1240000 observations completed
# 1241000 observations completed
# 1242000 observations completed
# 1243000 observations completed
# 1244000 observations completed
# 1245000 observations completed
# 1246000 observations completed
# 1247000 observations completed
# 1248000 observations completed
# 1249000 observations completed
# 1250000 observations completed
# 1251000 observations completed
# 1252000 observations completed
# 1253000 observations completed
# 1254000 observations completed
# 1255000 observations completed
# 1256000 observations completed
# 1257000 observations completed
# 1258000 observations completed
# 1259000 observations completed
# 1260000 observations completed
# 1261000 observations completed
# 1262000 observations completed
# 1263000 observations completed
# 1264000 observations completed
# 1265000 observations completed
# 1266000 observations completed
# 1267000 observations completed
# 1268000 observations completed
# 1269000 observations completed
# 1270000 observations completed
# 1271000 observations completed
# 1272000 observations completed
# 1273000 observations completed
# 1274000 observations completed
# 1275000 observations completed
# 1276000 observations completed
# 1277000 observations completed
# 1278000 observations completed
# 1279000 observations completed
# 1280000 observations completed
# 1281000 observations completed
# 1282000 observations completed
# 1283000 observations completed
# 1284000 observations completed
# 1285000 observations completed
# 1286000 observations completed
# 1287000 observations completed
# 1288000 observations completed
# 1289000 observations completed
# 1290000 observations completed
# 1291000 observations completed
# 1292000 observations completed
# 1293000 observations completed
# 1294000 observations completed
# 1295000 observations completed
# 1296000 observations completed
# 1297000 observations completed
# 1298000 observations completed
# 1299000 observations completed
# 1300000 observations completed
# 1301000 observations completed
# 1302000 observations completed
# 1303000 observations completed
# 1304000 observations completed
# 1305000 observations completed
# 1306000 observations completed
# 1307000 observations completed
# 1308000 observations completed
# 1309000 observations completed
# 1310000 observations completed
# 1311000 observations completed
# 1312000 observations completed
# 1313000 observations completed
# 1314000 observations completed
# 1315000 observations completed
# 1316000 observations completed
# 1317000 observations completed
# 1318000 observations completed
# 1319000 observations completed
# 1320000 observations completed
# 1321000 observations completed
# 1322000 observations completed
# 1323000 observations completed
# 1324000 observations completed
# 1325000 observations completed
# 1326000 observations completed
# 1327000 observations completed
# 1328000 observations completed
# 1329000 observations completed
# 1330000 observations completed
# 1331000 observations completed
# 1332000 observations completed
# 1333000 observations completed
# 1334000 observations completed
# 1335000 observations completed
# 1336000 observations completed
# 1337000 observations completed
# 1338000 observations completed
# 1339000 observations completed
# 1340000 observations completed
# 1341000 observations completed
# 1342000 observations completed
# 1343000 observations completed
# 1344000 observations completed
# 1345000 observations completed
# 1346000 observations completed
# 1347000 observations completed
# 1348000 observations completed
# 1349000 observations completed
# 1350000 observations completed
# 1351000 observations completed
# 1352000 observations completed
# 1353000 observations completed
# 1354000 observations completed
# 1355000 observations completed
# 1356000 observations completed
# 1357000 observations completed
# 1358000 observations completed
# 1359000 observations completed
# 1360000 observations completed
# 1361000 observations completed
# 1362000 observations completed
# 1363000 observations completed
# 1364000 observations completed
# 1365000 observations completed
# 1366000 observations completed
# 1367000 observations completed
# 1368000 observations completed
# 1369000 observations completed
# 1370000 observations completed
# 1371000 observations completed
# 1372000 observations completed
# 1373000 observations completed
# 1374000 observations completed
# 1375000 observations completed
# 1376000 observations completed
# 1377000 observations completed
# 1378000 observations completed
# 1379000 observations completed
# 1380000 observations completed
# 1381000 observations completed
# 1382000 observations completed
# 1383000 observations completed
# 1384000 observations completed
# 1385000 observations completed
# 1386000 observations completed
# 1387000 observations completed
# 1388000 observations completed
# 1389000 observations completed
# 1390000 observations completed
# 1391000 observations completed
# 1392000 observations completed
# 1393000 observations completed
# 1394000 observations completed
# 1395000 observations completed
# 1396000 observations completed
# 1397000 observations completed
# 1398000 observations completed
# 1399000 observations completed
# 1400000 observations completed
# 1401000 observations completed
# 1402000 observations completed
# 1403000 observations completed
# 1404000 observations completed
# 1405000 observations completed
# 1406000 observations completed
# 1407000 observations completed
# 1408000 observations completed
# 1409000 observations completed
# 1410000 observations completed
# 1411000 observations completed
# 1412000 observations completed
# 1413000 observations completed
# 1414000 observations completed
# 1415000 observations completed
# 1416000 observations completed
# 1417000 observations completed
# 1418000 observations completed
# 1419000 observations completed
# 1420000 observations completed
# 1421000 observations completed
# 1422000 observations completed
# 1423000 observations completed
# 1424000 observations completed
# 1425000 observations completed
# 1426000 observations completed
# 1427000 observations completed
# 1428000 observations completed
# 1429000 observations completed
# 1430000 observations completed
# 1431000 observations completed
# 1432000 observations completed
# 1433000 observations completed
# 1434000 observations completed
# 1435000 observations completed
# 1436000 observations completed
# 1437000 observations completed
# 1438000 observations completed
# 1439000 observations completed
# 1440000 observations completed
# 1441000 observations completed
# 1442000 observations completed
# 1443000 observations completed
# 1444000 observations completed
# 1445000 observations completed
# 2891247
# 289125

# %%
1445625

# %%
save = pd.DataFrame(RE288_col)
save.to_csv('RE288_5th_batch.csv')
