# %%
# Make sure we're in the right working directory. 
# %cd /Users/dcox/Dropbox/Projects/CurrentProjectManuscripts/Empirical/PersonalFun/Matching/KaggleWebscrapingAnalysis/data/
# Out:
# /Users/dcox/Dropbox/Projects/CurrentProjectManuscripts/Empirical/PersonalFun/Matching/KaggleWebscrapingAnalysis/data

# %%
# Packages!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in data
data = pd.read_csv('merged_data.csv')
data = data.drop(['Unnamed: 0'], axis=1)
df = data.copy()
df.head(20)
# Out:
#        px     pz  start_speed  end_speed  spin_rate  spin_dir  break_angle  \
# 0   0.416  2.963         92.9       84.1   2305.052   159.235        -25.0
# 1  -0.191  2.347         92.8       84.1   2689.935   151.402        -40.7
# 2  -0.518  3.284         94.1       85.2   2647.972   145.125        -43.7
# 3  -0.641  1.221         91.0       84.0   1289.590   169.751         -1.3
# 4  -1.821  2.083         75.4       69.6   1374.569   280.671         18.4
# 5   0.627  2.397         92.9       84.8   2743.856   148.110        -45.7
# 6  -1.088  1.610         93.3       85.3   2848.535   147.044        -46.3
# 7  -0.257  2.047         89.3       82.4   1433.743   185.948          7.3
# 8   1.470  2.350         92.1       85.0   2666.090   146.146        -45.0
# 9  -1.337  1.898         89.3       82.0   1384.143   174.388          2.0
# 10 -0.286  1.830         92.6       84.4   2475.323   137.145        -39.0
# 11  0.200  2.643         90.5       83.7   2186.173   119.214        -34.4
# 12 -0.741  2.930         90.6       83.0   2234.961   154.197        -25.5
# 13 -0.711  1.971         76.3       71.2    818.890   283.898         11.6
# 14 -1.539  1.525         91.6       84.5   2248.792   154.853        -23.8
# 15 -0.881  1.888         93.1       85.3   2697.793   151.814        -40.0
# 16  0.096  2.794         91.1       83.8   2214.735   148.444        -30.3
# 17 -0.365  1.518         92.4       84.6   2439.131   140.729        -37.2
# 18 -1.681  0.875         89.3       82.9   1000.504   187.948          7.0
# 19 -1.585  1.720         89.5       82.2   2357.290   230.354         38.0
#
#     break_length  break_y      ax  ...  batter_id      event       g_id  \
# 0            3.2     23.7   7.665  ...     572761  Groundout  201500001
# 1            3.4     23.7  12.043  ...     572761  Groundout  201500001
# 2            3.7     23.7  14.368  ...     572761  Groundout  201500001
# 3            5.0     23.8   2.104  ...     572761  Groundout  201500001
# 4           12.0     23.8 -10.280  ...     572761  Groundout  201500001
# 5            3.7     23.7  13.590  ...     572761  Groundout  201500001
# 6            3.6     23.7  14.549  ...     518792     Double  201500001
# 7            4.8     23.8  -1.339  ...     518792     Double  201500001
# 8            4.0     23.8  13.808  ...     407812     Single  201500001
# 9            4.9     23.8   1.218  ...     407812     Single  201500001
# 10           4.8     23.7  15.709  ...     407812     Single  201500001
# 11           6.3     23.8  17.411  ...     425509  Strikeout  201500001
# 12           3.7     23.8   8.889  ...     425509  Strikeout  201500001
# 13          11.0     23.9  -6.127  ...     425509  Strikeout  201500001
# 14           3.6     23.8   8.804  ...     571431  Strikeout  201500001
# 15           3.3     23.8  11.942  ...     571431  Strikeout  201500001
# 16           4.1     23.8  10.656  ...     571431  Strikeout  201500001
# 17           4.5     23.8  14.373  ...     571431  Strikeout  201500001
# 18           5.8     23.8  -1.244  ...     571431  Strikeout  201500001
# 19           6.0     23.8 -16.390  ...     451594     Double  201500001
#
#     inning  o  p_score  p_throws  pitcher_id  stand    top
# 0        1  1        0         L      452657      L   True
# 1        1  1        0         L      452657      L   True
# 2        1  1        0         L      452657      L   True
# 3        1  1        0         L      452657      L   True
# 4        1  1        0         L      452657      L   True
# 5        1  1        0         L      452657      L   True
# 6        1  1        0         L      452657      L   True
# 7        1  1        0         L      452657      L   True
# 8        1  1        0         L      452657      R   True
# 9        1  1        0         L      452657      R   True
# 10       1  1        0         L      452657      R   True
# 11       1  2        0         L      452657      R   True
# 12       1  2        0         L      452657      R   True
# 13       1  2        0         L      452657      R   True
# 14       1  3        0         L      452657      L   True
# 15       1  3        0         L      452657      L   True
# 16       1  3        0         L      452657      L   True
# 17       1  3        0         L      452657      L   True
# 18       1  3        0         L      452657      L   True
# 19       1  0        1         R      425794      L  False
#
# [20 rows x 50 columns]
